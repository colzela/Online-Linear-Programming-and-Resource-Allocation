# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Q1 = pd.read_csv("Q1l_norm.csv")
Q4 = pd.read_csv("Q4dua_price.csv")
Q6 = pd.read_csv("Q6price.csv")
Q1 = np.array(Q1)
Q4 = np.array(Q4)
Q6 = np.array(Q6)
index = [100*i for i in range(100)]


plt.plot(index, Q1, color='purple', linestyle='solid', linewidth=1, markersize=4, label="SLPM")
plt.plot(index, Q4, color='orange', linestyle='solid', linewidth=1, markersize=4, label="SCPM")
# plt.plot(index, Q6, color='red', linestyle='solid', linewidth=1, markersize=4, label="AHDL")
# plt.plot(index, l_ratio_withE, color='blue', linestyle='solid', linewidth=1, markersize=4, label="Dynamic(SCPM) with modify")
plt.xlabel("k")
plt.ylabel("norm of difference of dual price")
# plt.title("competetive ratio respect to different values of k in SLPM and SCPM")
plt.legend()
plt.savefig("norm_figure.jpg", dpi=400)
plt.show()
